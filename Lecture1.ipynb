# %% [markdown]
# <a href="https://colab.research.google.com/github/collinger/NSCI801/blob/main/Lecture1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

plt.style.use('dark_background')

x = np.linspace(-5, 5, 200)
mu1 = -.3
sigma = 1
plt.plot(x, stats.norm.pdf(x, mu1, sigma))
mu2 = .2
sigma = 1
plt.plot(x, stats.norm.pdf(x, mu2, sigma))
plt.show()
print("Effect size d =", abs((mu1-mu2)/sigma))
# Out:
# Effect size d = 0.5
